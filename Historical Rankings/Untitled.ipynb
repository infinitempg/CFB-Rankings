# %%
import json
import pandas as pd
import numpy as np
from tqdm.autonotebook import tqdm
from sklearn import preprocessing
import urllib
import os
import matplotlib.pyplot as plt
# Out:
# /Users/mike/anaconda3/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
def seasonProgression(dfR):
    totalGames = len(dfR)
    curWeek = int(dfR['week']) + 1
    return curWeek/(2*totalGames)

def winningTeam(dfR):
    if dfR['home_points'] > dfR['away_points']:
        return dfR['home_team']
    else:
        return dfR['away_team']
    
def teamWin(dfR, team):
    if dfR.winner == team:
        return True
    else:
        return False
    
def findOpp(dfR):
    if dfR.home == True:
        return dfR.away_team
    else:
        return dfR.home_team
def findOppConf(dfR):
    if dfR.home == True:
        return dfR.away_conference
    else:
        return dfR.home_conference
    
def locMult(dfR):
    if dfR['neutral_site'] == True:
        return 1.05
    elif dfR['home'] == True:
        return 1.1
    else:
        return 1.
    
def pointDiff(dfR,team):
    if dfR.home_team == team:
        return dfR.home_points - dfR.away_points
    else:
        return dfR.away_points - dfR.home_points
    
def confMult(dfR):
    if dfR.opp_conference in P5:
        return 1.
    elif dfR.opp_conference in G5:
        return 0.5
    else:
        return 0.15
    
def winQ(dfR,week,FBSdict): 
    if dfR.opp_conference == None:
        oppWinPct = 0.5
    else:
#         print(dfR.opp_conference)
        oppWinPct = FBSdict[dfR.opp].loc[FBSdict[dfR.opp].week <= week, 'winPct'].tail(1).item()
    
    if dfR.teamWin == True:
        winMult = 1
        oppFactor = oppWinPct
    else:
        winMult = -1
        oppFactor = 1 - oppWinPct
    
    return oppFactor * dfR.seasonProg * dfR.conf_mult * winMult*(dfR.loc_mult + 0.01*dfR.point_diff)

def calcPct(team, week,FBSdict):
    winqweek = 'win_q_'+str(week)
    wins = FBSdict[team].loc[FBSdict[team].week <= week, 'wins'].tail(1).item()
    losses = FBSdict[team].loc[FBSdict[team].week <= week, 'losses'].tail(1).item()
    return 0.9 * FBSdict[team][winqweek].mean() + 0.01*(wins-losses)

# %%
def getRanks(year):
    json_url = urllib.request.urlopen('https://api.collegefootballdata.com/games?year=%s&seasonType=regular'%year)
    jsonFile = json.loads(json_url.read())
    curSch = pd.DataFrame(jsonFile)
    
    curWeek = max(curSch['week'])
    
    json_url2 = urllib.request.urlopen('https://api.collegefootballdata.com/games?year=%s&seasonType=postseason'%year)
    jsonFile2 = json.loads(json_url2.read())
    postSch = pd.DataFrame(jsonFile2)
    postSch['week'] = postSch['week'] + curWeek
    curSch = curSch.append(postSch)
    curSch = curSch.dropna(subset=['away_points'])
    curSch.loc[curSch.away_team == 'Notre Dame','away_conference'] = 'Notre Dame'
    curSch.loc[curSch.home_team == 'Notre Dame','home_conference'] = 'Notre Dame'
    
    info_json_url = urllib.request.urlopen('https://api.collegefootballdata.com/teams/fbs?year=%s'%year)
    teamInfo = json.loads(info_json_url.read())
    teamInfo = pd.DataFrame(teamInfo)

    FBSteams = np.array(teamInfo.school)
    FBSteams.sort()

    FBSdict = {}
    for team in FBSteams:
        FBSdict[team] = curSch[(curSch['away_team'] == team) | 
                               (curSch['home_team'] == team)]
#         FBSdict[team] = FBSdict[team][np.isfinite(FBSdict[team].away_points)]
        FBSdict[team] = FBSdict[team].reset_index()

    FBSbar = tqdm(total=len(FBSteams),desc='Vars:',leave=False)
    for key in FBSdict:
        FBSbar.set_description('Vars: %s'%key)
        FBSdict[key]['seasonProg'] = FBSdict[key].apply(lambda row: seasonProgression(row),axis = 1)
        FBSdict[key]['winner'] = FBSdict[key].apply(lambda row: winningTeam(row),axis = 1)
        FBSdict[key]['teamWin'] = FBSdict[key].apply(lambda row: teamWin(row,key),axis = 1)

        wins = 0
        losses = 0
        winList = []
        lossList = []
        for row in FBSdict[key].itertuples():
        #     print(row.winner)
            if row.teamWin:
                wins += 1
            else:
                losses += 1
            winList.append(wins)
            lossList.append(losses)

        FBSdict[key]['wins'] = winList
        FBSdict[key]['losses'] = lossList

        hometeam = FBSdict[key]['home_team'] == key
        FBSdict[key]['home'] = hometeam

        FBSdict[key]['winPct'] = FBSdict[key]['wins']/(FBSdict[key]['losses'] + FBSdict[key]['wins'])
        FBSdict[key]['opp'] = FBSdict[key].apply(lambda row: findOpp(row), axis = 1)
        FBSdict[key]['opp_conference'] = FBSdict[key].apply(lambda row: findOppConf(row), axis = 1)
        FBSdict[key]['point_diff'] = FBSdict[key].apply(lambda row: pointDiff(row,key), axis = 1)
        FBSdict[key]['loc_mult'] = FBSdict[key].apply(lambda row: locMult(row), axis = 1)
        FBSdict[key]['conf_mult'] = FBSdict[key].apply(lambda row: confMult(row), axis = 1)

        FBSbar.update(1)
    FBSbar.close()
    
    FBSbar2 = tqdm(total=len(FBSteams),desc='WinQ:',leave=False)
    for key in FBSdict:
        FBSbar2.set_description('WinQ: %s'%key)
        for w in range(4,curWeek+1):
            FBSdict[key]['win_q_'+str(w)] = FBSdict[key].apply(lambda row: winQ(row, w, FBSdict),axis=1)
        FBSbar2.update()
    FBSbar2.close()
    
    FBSbar3 = tqdm(total=len(FBSteams),desc='PCT:',leave=False)
    FBSpct = {}
    for key in FBSdict:
        FBSbar3.set_description('PCT: %s'%key)
        pctList = []
        for w in range(4,curWeek+1):
            pctList.append(calcPct(key,w,FBSdict))
        FBSpct[key] = pctList
        FBSbar3.update()
    FBSbar3.close()
    
    if not os.path.exists(str(year)):
            os.mkdir(str(year))

    PCTdf = pd.DataFrame.from_dict(FBSpct,orient='index',columns=range(4,curWeek+1))
    PCTdf.to_csv('%s/PCT.csv'%year)

    PCTnormdf = pd.DataFrame(index = FBSteams,columns=range(4,curWeek+1))

    for w in range(4,curWeek+1):
        x = PCTdf[w].values.reshape(-1,1)
        min_max_scaler = preprocessing.MinMaxScaler()
        xScaled = min_max_scaler.fit_transform(x)
        PCTnormdf[w] = xScaled.reshape(len(FBSteams))

    PCTnormdf.to_csv('%s/PCT_norm.csv'%year)

    Ranks = PCTdf.rank(method='first',ascending=False).astype('int64')
    Ranks.to_csv('%s/Ranks.csv'%year)

    for w in range(4,curWeek+1):
        Wdf = pd.concat([PCTnormdf[w],Ranks[w]],axis=1)
        Wdf.columns = ['PCT','Rank']
        Wdf = Wdf.sort_values('Rank')
        Wdf.to_csv('%s/W%s.csv'%(year,w))

# %%
def plotTeamRank(team,teamInfo,Ranks,year,show=False):
    plt.figure(figsize=(12,5),facecolor='w')
    # plt.subplot(121)
    plt.gca().invert_yaxis()
    plt.title(team,size=18,fontweight='bold')
#     plt.title('Rankings over the 2019 CFB Season',size=14)
    plt.xlabel('Week',weight='medium')
    plt.ylabel('Rank',weight='medium')
    plt.xticks(fontname = 'NovaMono',weight='medium')
    plt.yticks(fontname = 'NovaMono',weight='medium')
    try:
        teamColor = teamInfo[teamInfo.school == team].color.item()
        teamAltColor = teamInfo[teamInfo.school == team].alt_color.item()
    except ValueError:
        teamColor = 'k'
        teamAltColor = 'w'
    plt.plot(Ranks.loc[team],c=teamColor,label=team,lw=5,
             marker = 'o',markersize=10,markerfacecolor=teamAltColor,markeredgewidth=2.5,markeredgecolor=teamColor)
    plt.tight_layout()
    if not os.path.exists(str(year)+'/Rank Graphs'):
            os.mkdir(str(year)+'/Rank Graphs')
    plt.savefig('%s/Rank Graphs/%s_%s_Ranks.png'%(year,team,year))
    if show:
        plt.show()
    else:
        plt.close()

def graphRanks(year):
    info_json_url = urllib.request.urlopen('https://api.collegefootballdata.com/teams/fbs?year=%s'%year)
    teamInfo = json.loads(info_json_url.read())
    teamInfo = pd.DataFrame(teamInfo)

    Ranks = pd.read_csv('%s/Ranks.csv'%year,index_col=0)
    PCT = pd.read_csv('%s/PCT.csv'%year,index_col=0)

    Ranks = Ranks.sort_values(str(max([int(r) for r in Ranks.columns])))

    TeamList = Ranks.index

    plt.rcParams['font.family'] = 'Roboto Mono'
    plt.rcParams['font.weight'] = 'medium'

    graphBar = tqdm(total=len(TeamList),leave=False)
#     print("Graphing:")
    for team in TeamList:
        graphBar.set_description('Graph: %s'%team)
        plotTeamRank(team,teamInfo,Ranks,year)
        graphBar.update(1)
    graphBar.close() 
    plt.figure(figsize=(12,7),facecolor='w')
    # plt.subplot(121)
    plt.gca().invert_yaxis()
    plt.title('Top Ten Teams',size=18,fontweight='bold')
    # plt.title('Rankings over the 2019 CFB Season',size=14)
    plt.xlabel('Week',weight='medium')
    plt.ylabel('Rank',weight='medium')
    plt.xticks(fontname = 'NovaMono',weight='medium')
    plt.yticks(fontname = 'NovaMono',weight='medium')
    teamColor = teamInfo[teamInfo.school == team].color.item()
    for team in TeamList[:10]:
        teamColor = teamInfo[teamInfo.school == team].color.item()
        teamAltColor = teamInfo[teamInfo.school == team].alt_color.item()
        plt.plot(Ranks.loc[team],c=teamColor,label=team,lw=5,
                 marker = 'o',markersize=10,markerfacecolor=teamAltColor,markeredgewidth=2.5,markeredgecolor=teamColor)
    plt.legend(bbox_to_anchor=(1, 1.025), loc='upper left', ncol=1)
    plt.tight_layout()
    plt.savefig('%s/topten.png'%year)
    plt.close()

    plt.figure(figsize=(12,8),facecolor='w')
    # plt.subplot(121)
    plt.gca().invert_yaxis()
    plt.title('Numbers 10 through 25',size=18,fontweight='bold')
    # plt.title('Rankings over the 2019 CFB Season',size=14)
    plt.xlabel('Week',weight='medium')
    plt.ylabel('Rank',weight='medium')
    plt.xticks(fontname = 'NovaMono',weight='medium')
    plt.yticks(fontname = 'NovaMono',weight='medium')
    teamColor = teamInfo[teamInfo.school == team].color.item()
    for team in TeamList[10:25]:
        teamColor = teamInfo[teamInfo.school == team].color.item()
        teamAltColor = teamInfo[teamInfo.school == team].alt_color.item()
        plt.plot(Ranks.loc[team],c=teamColor,label=team,lw=5,
                 marker = 'o',markersize=10,markerfacecolor=teamAltColor,markeredgewidth=2.5,markeredgecolor=teamColor)
    plt.legend(bbox_to_anchor=(1, 1.025), loc='upper left', ncol=1)
    plt.close()
    
    plt.figure(figsize=(12,8),facecolor='w')
    # plt.subplot(121)
    plt.gca().invert_yaxis()
    plt.title('Numbers 10 through 25',size=18,fontweight='bold')
    # plt.title('Rankings over the 2019 CFB Season',size=14)
    plt.xlabel('Week',weight='medium')
    plt.ylabel('Rank',weight='medium')
    plt.xticks(fontname = 'NovaMono',weight='medium')
    plt.yticks(fontname = 'NovaMono',weight='medium')
    teamColor = teamInfo[teamInfo.school == team].color.item()
    for team in TeamList[10:25]:
        teamColor = teamInfo[teamInfo.school == team].color.item()
        teamAltColor = teamInfo[teamInfo.school == team].alt_color.item()
        plt.plot(Ranks.loc[team],c=teamColor,label=team,lw=5,
                 marker = 'o',markersize=10,markerfacecolor=teamAltColor,markeredgewidth=2.5,markeredgecolor=teamColor)
    plt.legend(bbox_to_anchor=(1, 1.025), loc='upper left', ncol=1)
    plt.tight_layout()
    plt.savefig('%s/ranked.png'%year)
    plt.close()

    totalRise = Ranks['4'] - Ranks[str(max([int(r) for r in Ranks.columns]))]
    totalRise = totalRise.sort_values()
    biggestRises = totalRise.tail(5)
    biggestFalls = totalRise.head(5)

    plt.figure(figsize=(12,5),facecolor='w')
    # plt.subplot(121)
    plt.gca().invert_yaxis()
    plt.title('Biggest Risers',size=18,fontweight='bold')
    # plt.title('Rankings over the 2019 CFB Season',size=14)
    plt.xlabel('Week',weight='medium')
    plt.ylabel('Rank',weight='medium')
    plt.xticks(fontname = 'NovaMono',weight='medium')
    plt.yticks(fontname = 'NovaMono',weight='medium')
    teamColor = teamInfo[teamInfo.school == team].color.item()
    for team in biggestRises.index:
        teamColor = teamInfo[teamInfo.school == team].color.item()
        teamAltColor = teamInfo[teamInfo.school == team].alt_color.item()
        plt.plot(Ranks.loc[team],c=teamColor,label=team,lw=5,
                 marker = 'o',markersize=10,markerfacecolor=teamAltColor,markeredgewidth=2.5,markeredgecolor=teamColor)
    plt.legend(bbox_to_anchor=(1, 1.025), loc='upper left', ncol=1)
    plt.tight_layout()
    plt.savefig('%s/risers.png'%year)
    plt.close()
    
    plt.figure(figsize=(12,5),facecolor='w')
    # plt.subplot(121)
    plt.gca().invert_yaxis()
    plt.title('Biggest Falls',size=18,fontweight='bold')
    # plt.title('Rankings over the 2019 CFB Season',size=14)
    plt.xlabel('Week',weight='medium')
    plt.ylabel('Rank',weight='medium')
    plt.xticks(fontname = 'NovaMono',weight='medium')
    plt.yticks(fontname = 'NovaMono',weight='medium')
    teamColor = teamInfo[teamInfo.school == team].color.item()
    for team in biggestFalls.index:
        teamColor = teamInfo[teamInfo.school == team].color.item()
        teamAltColor = teamInfo[teamInfo.school == team].alt_color.item()
        plt.plot(Ranks.loc[team],c=teamColor,label=team,lw=5,
                 marker = 'o',markersize=10,markerfacecolor=teamAltColor,markeredgewidth=2.5,markeredgecolor=teamColor)
    plt.legend(bbox_to_anchor=(1, 1.025), loc='upper left', ncol=1)
    plt.tight_layout()
    plt.savefig('%s/falls.png'%year)
    plt.close()

# %%
ranks = pd.read_csv('2006/Ranks.csv')

# %%
for y in range(1980,1990):
    teamInfo = getTeamInfo(y)
    for c in teamInfo.conference.unique():
        if c not in P5 and c not in G5:
            print(c)
# Out:
# Southern
# Southland
# Ivy
# Big 8
# Missouri Valley
# PCAA
# Southern
# Southland
# Ivy
# Big 8
# Missouri Valley
# PCAA
# Big 8
# Missouri Valley
# PCAA
# Big 8
# Missouri Valley
# PCAA
# Big 8
# Missouri Valley
# PCAA
# Big 8
# Missouri Valley
# PCAA
# Big 8
# PCAA
# Big 8
# PCAA
# Big 8
# Big West
# Big 8
# Big West

# %%
P5 = ['ACC','Pac-12','Pac-10','Big East','Big Ten','Big 12','SEC','Notre Dame','Southwest','Big 8']
G5 = ['Conference USA','Sun Belt','Mid-American','American Athletic','Mountain West','FBS Independents','Western Athletic']

# %%
def getTeamInfo(year):
    info_json_url = urllib.request.urlopen('https://api.collegefootballdata.com/teams/fbs?year=%s'%year)
    teamInfo = json.loads(info_json_url.read())
    teamInfo = pd.DataFrame(teamInfo)
    return teamInfo

# %%
info2019 = getTeamInfo(2019)

# %%
info1990 = getTeamInfo(1980)

# %%
info1990
# Out:
#     abbreviation alt_color                    alt_name1 alt_name2  \
# 0            AFA   #ffffff                         None       AFA
# 1            ALA   #f1f2f3                         None       ALA
# 2            APP   #ffcd00                         None       APP
# 3           ARIZ   #00205b                         None      ARIZ
# 4            ASU   #f1f2f3                         None       ASU
# 5            ARK   #000000                         None       ARK
# 6           ARST   #000000                         None      ARST
# 7           ARMY   #231f20                         None      ARMY
# 8            AUB   #f1f2f3                         None       AUB
# 9           BALL   #ffffff                         None      BALL
# 10           BAY   #ffb81c                         None       BAY
# 11            BC   #a39161                         None        BC
# 12          BGSU   #492000          Bowling Green State      BGSU
# 13          BRWN   #949300                         None      BRWN
# 14           BYU   #ffffff                Brigham Young       BYU
# 15           CAL   #ffc423                         None       CAL
# 16           CMU   #ffffff                         None       CMU
# 17          CHAT   #dca71d                         None      CHAT
# 18           CIN   #717073                         None       CIN
# 19          CLEM   #522d80                         None      CLEM
# 20          COLG   #231f20                         None      COLG
# 21          COLO   #ffd200                         None      COLO
# 22           CSU   #ffc425                         None       CSU
# 23          CLMB   #004b85                         None      CLMB
# 24           COR   #101010                         None       COR
# 25          DART   #000000                         None      DART
# 26          DRKE   #c0c0c0                         None      DRKE
# 27          DUKE   #f1f2f3                         None      DUKE
# 28           ECU   #f0907b                         None       ECU
# 29           EMU   #f0f0f0                         None       EMU
# ..           ...       ...                          ...       ...
# 108          TOL   #ffd51d                         None       TOL
# 109         TULN   #3baf29                         None      TULN
# 110         TLSA   #ee3b33                         None      TLSA
# 111         UCLA   #ffc72c                         None      UCLA
# 112         UNLV   #c2c4c6             Nevada-Las Vegas      UNLV
# 113          USC   #ffc72c                         None       USC
# 114         UTAH   #7e8083                         None      UTAH
# 115          USU   #949ca1                         None       USU
# 116         UTEP   #ff6f12                Texas-El Paso      UTEP
# 117          VAN   #231f20                         None       VAN
# 118         NOVA   #f0f0f0                         None      NOVA
# 119          UVA   #002d62                         None       UVA
# 120           VT   #c2c1ba                         None        VT
# 121          VMI   #eec52b  Virginia Military Institute       VMI
# 122         WAKE   #000000                         None      WAKE
# 123         WASH   #e8e3d3                         None      WASH
# 124          WSU   #6a747c                         None       WSU
# 125          WCU   #bf9e70                         None       WCU
# 126          WMU   #bfa979                         None       WMU
# 127          WES      None                         None       WES
# 128          WVU   #eaaa00                         None       WVU
# 129          W&M   #f6b220                         None       W&M
# 130          WIS   #f7f7f7                         None       WIS
# 131          WYO   #ffffff                         None       WYO
# 132         YALE   #286dc0                         None      YALE
# 133         None      None                         None      None
# 134          LBS      None                         None       LBS
# 135         None      None                         None      None
# 136         None      None                         None      None
# 137         None      None                         None      None
#
#                alt_name3    color         conference division       id  \
# 0              Air Force  #004a7b   Western Athletic     None     2005
# 1                Alabama  #690014                SEC     None      333
# 2         Appalachian St  #000000           Southern     None     2026
# 3                Arizona  #002449             Pac-10     None       12
# 4          Arizona State  #942139             Pac-10     None        9
# 5               Arkansas  #9c1831          Southwest     None        8
# 6         Arkansas State  #e81018          Southland     None     2032
# 7                   Army  #ce9c00   FBS Independents     None      349
# 8                 Auburn  #03244d                SEC     None        2
# 9             Ball State  #DA0000       Mid-American     None     2050
# 10                Baylor  #004834          Southwest     None      239
# 11        Boston College  #88001a                ACC     None      103
# 12         Bowling Green  #2b1000       Mid-American     None      189
# 13                 Brown  #411e09                Ivy     None      225
# 14                   BYU  #001E4C   Western Athletic     None      252
# 15                   Cal  #031522             Pac-10     None       25
# 16         Cent Michigan  #6a0032       Mid-American     None     2117
# 17           Chattanooga  #00386b           Southern     None      236
# 18            Cincinnati  #000000  American Athletic     None     2132
# 19               Clemson  #F66733                ACC     None      228
# 20               Colgate  #8B011D   FBS Independents     None     2142
# 21              Colorado  #d1c57e              Big 8     None       38
# 22        Colorado State  #004537   Western Athletic     None       36
# 23              Columbia  #174785                Ivy     None      171
# 24               Cornell  #d60027                Ivy     None      172
# 25             Dartmouth  #005730                Ivy     None      159
# 26                 Drake  #004477    Missouri Valley     None     2181
# 27                  Duke  #001A57                ACC     None      150
# 28                   ECU  #4b1869   FBS Independents     None      151
# 29            E Michigan  #00331b       Mid-American     None     2199
# ..                   ...      ...                ...      ...      ...
# 108               Toledo  #00488F       Mid-American     None     2649
# 109               Tulane  #005837   FBS Independents     None     2655
# 110                Tulsa  #004371    Missouri Valley     None      202
# 111                 UCLA  #005C8E             Pac-10     None       26
# 112                 UNLV  #000000   FBS Independents     None     2439
# 113                  USC  #AE2531             Pac-10     None       30
# 114                 Utah  #890012   Western Athletic     None      254
# 115           Utah State  #003263               PCAA     None      328
# 116                 UTEP  #002843   Western Athletic     None     2638
# 117           Vanderbilt  #000000                SEC     None      238
# 118            Villanova  #123d7C   FBS Independents     None      222
# 119                  UVA  #00204e                ACC     None      258
# 120                   VT  #74232D   FBS Independents     None      259
# 121                  VMI  #E52D37           Southern     None     2678
# 122          Wake Forest  #9E7E38                ACC     None      154
# 123           Washington  #2B2F64             Pac-10     None      264
# 124        Washington St  #94022a             Pac-10     None      265
# 125           W Carolina  #492F91           Southern     None     2717
# 126           W Michigan  #B59966       Mid-American     None     2711
# 127       West Texas A&M  #000000    Missouri Valley     None     2704
# 128        West Virginia  #FFC600   FBS Independents     None      277
# 129       William & Mary  #103217   FBS Independents     None     2729
# 130            Wisconsin  #A00001            Big Ten     None      275
# 131              Wyoming  #533B22   Western Athletic     None     2751
# 132                 Yale  #004a81                Ivy     None       43
# 133  Cal State Fullerton     None               PCAA     None  1000012
# 134     Long Beach State     None               PCAA     None  1000006
# 135              Pacific     None               PCAA     None  1000044
# 136      Texas-Arlington     None          Southland     None  1000058
# 137        Wichita State     None    Missouri Valley     None  1000063
#
#                                                  logos            mascot  \
# 0    [http://a.espncdn.com/i/teamlogos/ncaa/500/200...           Falcons
# 1    [http://a.espncdn.com/i/teamlogos/ncaa/500/333...      Crimson Tide
# 2    [http://a.espncdn.com/i/teamlogos/ncaa/500/202...      Mountaineers
# 3    [http://a.espncdn.com/i/teamlogos/ncaa/500/12....          Wildcats
# 4    [http://a.espncdn.com/i/teamlogos/ncaa/500/9.p...        Sun Devils
# 5    [http://a.espncdn.com/i/teamlogos/ncaa/500/8.p...        Razorbacks
# 6    [http://a.espncdn.com/i/teamlogos/ncaa/500/203...        Red Wolves
# 7    [http://a.espncdn.com/i/teamlogos/ncaa/500/349...     Black Knights
# 8    [http://a.espncdn.com/i/teamlogos/ncaa/500/2.p...            Tigers
# 9    [http://a.espncdn.com/i/teamlogos/ncaa/500/205...         Cardinals
# 10   [http://a.espncdn.com/i/teamlogos/ncaa/500/239...             Bears
# 11   [http://a.espncdn.com/i/teamlogos/ncaa/500/103...            Eagles
# 12   [http://a.espncdn.com/i/teamlogos/ncaa/500/189...           Falcons
# 13   [http://a.espncdn.com/i/teamlogos/ncaa/500/225...             Bears
# 14   [http://a.espncdn.com/i/teamlogos/ncaa/500/252...           Cougars
# 15   [http://a.espncdn.com/i/teamlogos/ncaa/500/25....      Golden Bears
# 16   [http://a.espncdn.com/i/teamlogos/ncaa/500/211...         Chippewas
# 17   [http://a.espncdn.com/i/teamlogos/ncaa/500/236...              Mocs
# 18   [http://a.espncdn.com/i/teamlogos/ncaa/500/213...          Bearcats
# 19   [http://a.espncdn.com/i/teamlogos/ncaa/500/228...            Tigers
# 20   [http://a.espncdn.com/i/teamlogos/ncaa/500/214...           Raiders
# 21   [http://a.espncdn.com/i/teamlogos/ncaa/500/38....         Buffaloes
# 22   [http://a.espncdn.com/i/teamlogos/ncaa/500/36....              Rams
# 23   [http://a.espncdn.com/i/teamlogos/ncaa/500/171...             Lions
# 24   [http://a.espncdn.com/i/teamlogos/ncaa/500/172...           Big Red
# 25   [http://a.espncdn.com/i/teamlogos/ncaa/500/159...         Big Green
# 26   [http://a.espncdn.com/i/teamlogos/ncaa/500/218...          Bulldogs
# 27   [http://a.espncdn.com/i/teamlogos/ncaa/500/150...       Blue Devils
# 28   [http://a.espncdn.com/i/teamlogos/ncaa/500/151...           Pirates
# 29   [http://a.espncdn.com/i/teamlogos/ncaa/500/219...            Eagles
# ..                                                 ...               ...
# 108  [http://a.espncdn.com/i/teamlogos/ncaa/500/264...           Rockets
# 109  [http://a.espncdn.com/i/teamlogos/ncaa/500/265...        Green Wave
# 110  [http://a.espncdn.com/i/teamlogos/ncaa/500/202...  Golden Hurricane
# 111  [http://a.espncdn.com/i/teamlogos/ncaa/500/26....            Bruins
# 112  [http://a.espncdn.com/i/teamlogos/ncaa/500/243...            Rebels
# 113  [http://a.espncdn.com/i/teamlogos/ncaa/500/30....           Trojans
# 114  [http://a.espncdn.com/i/teamlogos/ncaa/500/254...              Utes
# 115  [http://a.espncdn.com/i/teamlogos/ncaa/500/328...            Aggies
# 116  [http://a.espncdn.com/i/teamlogos/ncaa/500/263...            Miners
# 117  [http://a.espncdn.com/i/teamlogos/ncaa/500/238...        Commodores
# 118  [http://a.espncdn.com/i/teamlogos/ncaa/500/222...          Wildcats
# 119  [http://a.espncdn.com/i/teamlogos/ncaa/500/258...         Cavaliers
# 120  [http://a.espncdn.com/i/teamlogos/ncaa/500/259...            Hokies
# 121  [http://a.espncdn.com/i/teamlogos/ncaa/500/267...           Keydets
# 122  [http://a.espncdn.com/i/teamlogos/ncaa/500/154...     Demon Deacons
# 123  [http://a.espncdn.com/i/teamlogos/ncaa/500/264...           Huskies
# 124  [http://a.espncdn.com/i/teamlogos/ncaa/500/265...           Cougars
# 125  [http://a.espncdn.com/i/teamlogos/ncaa/500/271...        Catamounts
# 126  [http://a.espncdn.com/i/teamlogos/ncaa/500/271...           Broncos
# 127  [http://a.espncdn.com/i/teamlogos/ncaa/500/270...         Buffaloes
# 128  [http://a.espncdn.com/i/teamlogos/ncaa/500/277...      Mountaineers
# 129  [http://a.espncdn.com/i/teamlogos/ncaa/500/272...             Tribe
# 130  [http://a.espncdn.com/i/teamlogos/ncaa/500/275...           Badgers
# 131  [http://a.espncdn.com/i/teamlogos/ncaa/500/275...           Cowboys
# 132  [http://a.espncdn.com/i/teamlogos/ncaa/500/43....          Bulldogs
# 133                                               None            Titans
# 134                                               None             49ers
# 135                                               None            Tigers
# 136                                               None         Mavericks
# 137                                               None          Shockers
#
#                   school
# 0              Air Force
# 1                Alabama
# 2      Appalachian State
# 3                Arizona
# 4          Arizona State
# 5               Arkansas
# 6         Arkansas State
# 7                   Army
# 8                 Auburn
# 9             Ball State
# 10                Baylor
# 11        Boston College
# 12         Bowling Green
# 13                 Brown
# 14                   BYU
# 15            California
# 16      Central Michigan
# 17           Chattanooga
# 18            Cincinnati
# 19               Clemson
# 20               Colgate
# 21              Colorado
# 22        Colorado State
# 23              Columbia
# 24               Cornell
# 25             Dartmouth
# 26                 Drake
# 27                  Duke
# 28         East Carolina
# 29      Eastern Michigan
# ..                   ...
# 108               Toledo
# 109               Tulane
# 110                Tulsa
# 111                 UCLA
# 112                 UNLV
# 113                  USC
# 114                 Utah
# 115           Utah State
# 116                 UTEP
# 117           Vanderbilt
# 118            Villanova
# 119             Virginia
# 120        Virginia Tech
# 121                  VMI
# 122          Wake Forest
# 123           Washington
# 124     Washington State
# 125     Western Carolina
# 126     Western Michigan
# 127       West Texas A&M
# 128        West Virginia
# 129       William & Mary
# 130            Wisconsin
# 131              Wyoming
# 132                 Yale
# 133  Cal State Fullerton
# 134     Long Beach State
# 135              Pacific
# 136      Texas-Arlington
# 137        Wichita State
#
# [138 rows x 12 columns]

# %%
for t in info1990.index:
    if info1990.loc[t].conference == "FBS Independents":
        print(info1990.loc[t].school)
        try:
            conf2019 = info2019[info2019.school == info1990.loc[t].school].conference.item()
        except ValueError:
            conf2019 = info1990.loc[t].conference
        print(conf2019)
        info1990.at[t,'conference'] = conf2019
# Out:
# Army
# FBS Independents
# Colgate
# FBS Independents
# East Carolina
# American Athletic
# Florida State
# ACC
# Georgia Tech
# ACC
# Holy Cross
# FBS Independents
# Illinois State
# FBS Independents
# Louisiana Monroe
# Sun Belt
# Louisville
# ACC
# Memphis
# American Athletic
# Miami
# ACC
# Navy
# American Athletic
# North Texas
# Conference USA
# Notre Dame
# FBS Independents
# Penn State
# Big Ten
# Pittsburgh
# ACC
# Richmond
# FBS Independents
# Rutgers
# Big Ten
# South Carolina
# SEC
# Southern Mississippi
# Conference USA
# Syracuse
# ACC
# Temple
# American Athletic
# Tulane
# American Athletic
# UNLV
# Mountain West
# Villanova
# FBS Independents
# Virginia Tech
# ACC
# West Virginia
# Big 12
# William & Mary
# FBS Independents

# %%
# info1990.at[1,'conference'] = 'pizza'

# %%
info1990
# Out:
#     abbreviation alt_color                    alt_name1 alt_name2  \
# 0            AFA   #ffffff                         None       AFA
# 1            ALA   #f1f2f3                         None       ALA
# 2            APP   #ffcd00                         None       APP
# 3           ARIZ   #00205b                         None      ARIZ
# 4            ASU   #f1f2f3                         None       ASU
# 5            ARK   #000000                         None       ARK
# 6           ARST   #000000                         None      ARST
# 7           ARMY   #231f20                         None      ARMY
# 8            AUB   #f1f2f3                         None       AUB
# 9           BALL   #ffffff                         None      BALL
# 10           BAY   #ffb81c                         None       BAY
# 11            BC   #a39161                         None        BC
# 12          BGSU   #492000          Bowling Green State      BGSU
# 13          BRWN   #949300                         None      BRWN
# 14           BYU   #ffffff                Brigham Young       BYU
# 15           CAL   #ffc423                         None       CAL
# 16           CMU   #ffffff                         None       CMU
# 17          CHAT   #dca71d                         None      CHAT
# 18           CIN   #717073                         None       CIN
# 19          CLEM   #522d80                         None      CLEM
# 20          COLG   #231f20                         None      COLG
# 21          COLO   #ffd200                         None      COLO
# 22           CSU   #ffc425                         None       CSU
# 23          CLMB   #004b85                         None      CLMB
# 24           COR   #101010                         None       COR
# 25          DART   #000000                         None      DART
# 26          DRKE   #c0c0c0                         None      DRKE
# 27          DUKE   #f1f2f3                         None      DUKE
# 28           ECU   #f0907b                         None       ECU
# 29           EMU   #f0f0f0                         None       EMU
# ..           ...       ...                          ...       ...
# 108          TOL   #ffd51d                         None       TOL
# 109         TULN   #3baf29                         None      TULN
# 110         TLSA   #ee3b33                         None      TLSA
# 111         UCLA   #ffc72c                         None      UCLA
# 112         UNLV   #c2c4c6             Nevada-Las Vegas      UNLV
# 113          USC   #ffc72c                         None       USC
# 114         UTAH   #7e8083                         None      UTAH
# 115          USU   #949ca1                         None       USU
# 116         UTEP   #ff6f12                Texas-El Paso      UTEP
# 117          VAN   #231f20                         None       VAN
# 118         NOVA   #f0f0f0                         None      NOVA
# 119          UVA   #002d62                         None       UVA
# 120           VT   #c2c1ba                         None        VT
# 121          VMI   #eec52b  Virginia Military Institute       VMI
# 122         WAKE   #000000                         None      WAKE
# 123         WASH   #e8e3d3                         None      WASH
# 124          WSU   #6a747c                         None       WSU
# 125          WCU   #bf9e70                         None       WCU
# 126          WMU   #bfa979                         None       WMU
# 127          WES      None                         None       WES
# 128          WVU   #eaaa00                         None       WVU
# 129          W&M   #f6b220                         None       W&M
# 130          WIS   #f7f7f7                         None       WIS
# 131          WYO   #ffffff                         None       WYO
# 132         YALE   #286dc0                         None      YALE
# 133         None      None                         None      None
# 134          LBS      None                         None       LBS
# 135         None      None                         None      None
# 136         None      None                         None      None
# 137         None      None                         None      None
#
#                alt_name3    color         conference division       id  \
# 0              Air Force  #004a7b   Western Athletic     None     2005
# 1                Alabama  #690014                SEC     None      333
# 2         Appalachian St  #000000           Southern     None     2026
# 3                Arizona  #002449             Pac-10     None       12
# 4          Arizona State  #942139             Pac-10     None        9
# 5               Arkansas  #9c1831          Southwest     None        8
# 6         Arkansas State  #e81018          Southland     None     2032
# 7                   Army  #ce9c00   FBS Independents     None      349
# 8                 Auburn  #03244d                SEC     None        2
# 9             Ball State  #DA0000       Mid-American     None     2050
# 10                Baylor  #004834          Southwest     None      239
# 11        Boston College  #88001a                ACC     None      103
# 12         Bowling Green  #2b1000       Mid-American     None      189
# 13                 Brown  #411e09                Ivy     None      225
# 14                   BYU  #001E4C   Western Athletic     None      252
# 15                   Cal  #031522             Pac-10     None       25
# 16         Cent Michigan  #6a0032       Mid-American     None     2117
# 17           Chattanooga  #00386b           Southern     None      236
# 18            Cincinnati  #000000  American Athletic     None     2132
# 19               Clemson  #F66733                ACC     None      228
# 20               Colgate  #8B011D   FBS Independents     None     2142
# 21              Colorado  #d1c57e              Big 8     None       38
# 22        Colorado State  #004537   Western Athletic     None       36
# 23              Columbia  #174785                Ivy     None      171
# 24               Cornell  #d60027                Ivy     None      172
# 25             Dartmouth  #005730                Ivy     None      159
# 26                 Drake  #004477    Missouri Valley     None     2181
# 27                  Duke  #001A57                ACC     None      150
# 28                   ECU  #4b1869   FBS Independents     None      151
# 29            E Michigan  #00331b       Mid-American     None     2199
# ..                   ...      ...                ...      ...      ...
# 108               Toledo  #00488F       Mid-American     None     2649
# 109               Tulane  #005837   FBS Independents     None     2655
# 110                Tulsa  #004371    Missouri Valley     None      202
# 111                 UCLA  #005C8E             Pac-10     None       26
# 112                 UNLV  #000000   FBS Independents     None     2439
# 113                  USC  #AE2531             Pac-10     None       30
# 114                 Utah  #890012   Western Athletic     None      254
# 115           Utah State  #003263               PCAA     None      328
# 116                 UTEP  #002843   Western Athletic     None     2638
# 117           Vanderbilt  #000000                SEC     None      238
# 118            Villanova  #123d7C   FBS Independents     None      222
# 119                  UVA  #00204e                ACC     None      258
# 120                   VT  #74232D   FBS Independents     None      259
# 121                  VMI  #E52D37           Southern     None     2678
# 122          Wake Forest  #9E7E38                ACC     None      154
# 123           Washington  #2B2F64             Pac-10     None      264
# 124        Washington St  #94022a             Pac-10     None      265
# 125           W Carolina  #492F91           Southern     None     2717
# 126           W Michigan  #B59966       Mid-American     None     2711
# 127       West Texas A&M  #000000    Missouri Valley     None     2704
# 128        West Virginia  #FFC600   FBS Independents     None      277
# 129       William & Mary  #103217   FBS Independents     None     2729
# 130            Wisconsin  #A00001            Big Ten     None      275
# 131              Wyoming  #533B22   Western Athletic     None     2751
# 132                 Yale  #004a81                Ivy     None       43
# 133  Cal State Fullerton     None               PCAA     None  1000012
# 134     Long Beach State     None               PCAA     None  1000006
# 135              Pacific     None               PCAA     None  1000044
# 136      Texas-Arlington     None          Southland     None  1000058
# 137        Wichita State     None    Missouri Valley     None  1000063
#
#                                                  logos            mascot  \
# 0    [http://a.espncdn.com/i/teamlogos/ncaa/500/200...           Falcons
# 1    [http://a.espncdn.com/i/teamlogos/ncaa/500/333...      Crimson Tide
# 2    [http://a.espncdn.com/i/teamlogos/ncaa/500/202...      Mountaineers
# 3    [http://a.espncdn.com/i/teamlogos/ncaa/500/12....          Wildcats
# 4    [http://a.espncdn.com/i/teamlogos/ncaa/500/9.p...        Sun Devils
# 5    [http://a.espncdn.com/i/teamlogos/ncaa/500/8.p...        Razorbacks
# 6    [http://a.espncdn.com/i/teamlogos/ncaa/500/203...        Red Wolves
# 7    [http://a.espncdn.com/i/teamlogos/ncaa/500/349...     Black Knights
# 8    [http://a.espncdn.com/i/teamlogos/ncaa/500/2.p...            Tigers
# 9    [http://a.espncdn.com/i/teamlogos/ncaa/500/205...         Cardinals
# 10   [http://a.espncdn.com/i/teamlogos/ncaa/500/239...             Bears
# 11   [http://a.espncdn.com/i/teamlogos/ncaa/500/103...            Eagles
# 12   [http://a.espncdn.com/i/teamlogos/ncaa/500/189...           Falcons
# 13   [http://a.espncdn.com/i/teamlogos/ncaa/500/225...             Bears
# 14   [http://a.espncdn.com/i/teamlogos/ncaa/500/252...           Cougars
# 15   [http://a.espncdn.com/i/teamlogos/ncaa/500/25....      Golden Bears
# 16   [http://a.espncdn.com/i/teamlogos/ncaa/500/211...         Chippewas
# 17   [http://a.espncdn.com/i/teamlogos/ncaa/500/236...              Mocs
# 18   [http://a.espncdn.com/i/teamlogos/ncaa/500/213...          Bearcats
# 19   [http://a.espncdn.com/i/teamlogos/ncaa/500/228...            Tigers
# 20   [http://a.espncdn.com/i/teamlogos/ncaa/500/214...           Raiders
# 21   [http://a.espncdn.com/i/teamlogos/ncaa/500/38....         Buffaloes
# 22   [http://a.espncdn.com/i/teamlogos/ncaa/500/36....              Rams
# 23   [http://a.espncdn.com/i/teamlogos/ncaa/500/171...             Lions
# 24   [http://a.espncdn.com/i/teamlogos/ncaa/500/172...           Big Red
# 25   [http://a.espncdn.com/i/teamlogos/ncaa/500/159...         Big Green
# 26   [http://a.espncdn.com/i/teamlogos/ncaa/500/218...          Bulldogs
# 27   [http://a.espncdn.com/i/teamlogos/ncaa/500/150...       Blue Devils
# 28   [http://a.espncdn.com/i/teamlogos/ncaa/500/151...           Pirates
# 29   [http://a.espncdn.com/i/teamlogos/ncaa/500/219...            Eagles
# ..                                                 ...               ...
# 108  [http://a.espncdn.com/i/teamlogos/ncaa/500/264...           Rockets
# 109  [http://a.espncdn.com/i/teamlogos/ncaa/500/265...        Green Wave
# 110  [http://a.espncdn.com/i/teamlogos/ncaa/500/202...  Golden Hurricane
# 111  [http://a.espncdn.com/i/teamlogos/ncaa/500/26....            Bruins
# 112  [http://a.espncdn.com/i/teamlogos/ncaa/500/243...            Rebels
# 113  [http://a.espncdn.com/i/teamlogos/ncaa/500/30....           Trojans
# 114  [http://a.espncdn.com/i/teamlogos/ncaa/500/254...              Utes
# 115  [http://a.espncdn.com/i/teamlogos/ncaa/500/328...            Aggies
# 116  [http://a.espncdn.com/i/teamlogos/ncaa/500/263...            Miners
# 117  [http://a.espncdn.com/i/teamlogos/ncaa/500/238...        Commodores
# 118  [http://a.espncdn.com/i/teamlogos/ncaa/500/222...          Wildcats
# 119  [http://a.espncdn.com/i/teamlogos/ncaa/500/258...         Cavaliers
# 120  [http://a.espncdn.com/i/teamlogos/ncaa/500/259...            Hokies
# 121  [http://a.espncdn.com/i/teamlogos/ncaa/500/267...           Keydets
# 122  [http://a.espncdn.com/i/teamlogos/ncaa/500/154...     Demon Deacons
# 123  [http://a.espncdn.com/i/teamlogos/ncaa/500/264...           Huskies
# 124  [http://a.espncdn.com/i/teamlogos/ncaa/500/265...           Cougars
# 125  [http://a.espncdn.com/i/teamlogos/ncaa/500/271...        Catamounts
# 126  [http://a.espncdn.com/i/teamlogos/ncaa/500/271...           Broncos
# 127  [http://a.espncdn.com/i/teamlogos/ncaa/500/270...         Buffaloes
# 128  [http://a.espncdn.com/i/teamlogos/ncaa/500/277...      Mountaineers
# 129  [http://a.espncdn.com/i/teamlogos/ncaa/500/272...             Tribe
# 130  [http://a.espncdn.com/i/teamlogos/ncaa/500/275...           Badgers
# 131  [http://a.espncdn.com/i/teamlogos/ncaa/500/275...           Cowboys
# 132  [http://a.espncdn.com/i/teamlogos/ncaa/500/43....          Bulldogs
# 133                                               None            Titans
# 134                                               None             49ers
# 135                                               None            Tigers
# 136                                               None         Mavericks
# 137                                               None          Shockers
#
#                   school
# 0              Air Force
# 1                Alabama
# 2      Appalachian State
# 3                Arizona
# 4          Arizona State
# 5               Arkansas
# 6         Arkansas State
# 7                   Army
# 8                 Auburn
# 9             Ball State
# 10                Baylor
# 11        Boston College
# 12         Bowling Green
# 13                 Brown
# 14                   BYU
# 15            California
# 16      Central Michigan
# 17           Chattanooga
# 18            Cincinnati
# 19               Clemson
# 20               Colgate
# 21              Colorado
# 22        Colorado State
# 23              Columbia
# 24               Cornell
# 25             Dartmouth
# 26                 Drake
# 27                  Duke
# 28         East Carolina
# 29      Eastern Michigan
# ..                   ...
# 108               Toledo
# 109               Tulane
# 110                Tulsa
# 111                 UCLA
# 112                 UNLV
# 113                  USC
# 114                 Utah
# 115           Utah State
# 116                 UTEP
# 117           Vanderbilt
# 118            Villanova
# 119             Virginia
# 120        Virginia Tech
# 121                  VMI
# 122          Wake Forest
# 123           Washington
# 124     Washington State
# 125     Western Carolina
# 126     Western Michigan
# 127       West Texas A&M
# 128        West Virginia
# 129       William & Mary
# 130            Wisconsin
# 131              Wyoming
# 132                 Yale
# 133  Cal State Fullerton
# 134     Long Beach State
# 135              Pacific
# 136      Texas-Arlington
# 137        Wichita State
#
# [138 rows x 12 columns]
